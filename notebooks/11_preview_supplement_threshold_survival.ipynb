# %% [markdown]
# # Preview Supplement Threshold Survival
#
# Displays the current paper-mode supplement figure from `../figures/paper/supplement_threshold_survival.png`.

# %%
from pathlib import Path
from IPython.display import Image, display

figure_path = Path('../figures/paper/supplement_threshold_survival.png')
assert figure_path.exists(), figure_path

display(Image(filename=str(figure_path)))
figure_path.resolve()
# Out:
# PosixPath('/Users/michaelcarr/Desktop/Semantic vs Syntactic/modelb_semantic_jsri_repo/figures/paper/supplement_threshold_survival.png')
