# %% [markdown]
# # Preview Figure 5
#
# Displays the current paper-mode frontiers and robustness figure from `../figures/paper/figure_5_frontiers_and_robustness.png`.

# %%
from pathlib import Path
from IPython.display import Image, display

figure_path = Path('../figures/paper/figure_5_frontiers_and_robustness.png')
assert figure_path.exists(), figure_path

display(Image(filename=str(figure_path)))
figure_path.resolve()
# Out:
# PosixPath('/Users/michaelcarr/Desktop/Semantic vs Syntactic/modelb_semantic_jsri_repo/figures/paper/figure_5_frontiers_and_robustness.png')

# %% [markdown]
# \caption{\textbf{Intervention frontiers distinguish sequence-selective semantic organization from sequence-agnostic syntactic correlation.}
# (a) Information--viability frontier for the sequence-selective regime at inheritance fidelity $0.9$.
# (b) Information--viability frontier for the sequence-agnostic regime at inheritance fidelity $0.9$.
# Points show individual coarse-graining interventions, colored by intervention family. Lines show the monotone upper information--viability frontier for each regime. Dashed horizontal lines indicate actual viability, and dashed vertical lines indicate the corresponding semantic-information estimate. Panel (c) shows the difference between actual viability and the maximum viability recovered on the intervention frontier across inheritance fidelity. Dashed lines mark the actual viability level and corresponding semantic-information estimate.
# (c) Difference between actual viability and frontier maximum across inheritance fidelity.
# Sequence-selective systems show a positive viability advantage, whereas sequence-agnostic systems remain near or below zero.}
