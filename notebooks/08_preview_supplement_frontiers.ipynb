# %% [markdown]
# # Preview Supplement Frontiers
#
# Displays the current paper-mode supplement figure from `../figures/paper/supplement_frontiers.png`.

# %%
from pathlib import Path
from IPython.display import Image, display

figure_path = Path('../figures/paper/supplement_frontiers.png')
assert figure_path.exists(), figure_path

display(Image(filename=str(figure_path)))
figure_path.resolve()
# Out:
# PosixPath('/Users/michaelcarr/Desktop/Semantic vs Syntactic/modelb_semantic_jsri_repo/figures/paper/supplement_frontiers.png')

# %% [markdown]
# \caption{\textbf{Representative intervention frontiers across viability definitions and control regimes.}
# Information--viability frontiers for selected intervention analyses.
# (a) Sequence-selective excess-over-control frontier at inheritance fidelity $0.9$, showing a structured increase in viability as preserved motif--metabolite information increases.
# (b) Sequence-selective negative local-configuration entropy frontier at inheritance fidelity $0.9$.
# For entropy-based definitions, viability is defined as negative entropy and can therefore take negative values; panel (b) uses a compressed y-axis to show the small change in this score.
# (c) Sequence-selective threshold-survival frontier at inheritance fidelity $1.0$, showing a step-like viability response.
# (d) Sequence-agnostic excess-over-control frontier at inheritance fidelity $1.0$.
# Together, these examples show that high-viability frontiers are recovered for biologically aligned sequence-selective criteria, whereas generic entropy-state definitions and sequence-agnostic controls do not recover comparable semantic structure.}

# %%
Representative frontiers across additional viability definitions and control regimes are shown in Fig. S1, illustrating that high-viability frontiers are recovered for biologically aligned sequence-selective criteria but not for generic entropy-state definitions or sequence-agnostic controls.
