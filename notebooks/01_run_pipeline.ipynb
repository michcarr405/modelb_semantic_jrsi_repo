# %% [markdown]
# # Run Model B JSRI semantic pipeline
#
# Runs the original Model B baseline plus intervention-based semantic analysis. Use `fast` first, then `medium` or `paper`.

# %%
from pathlib import Path
import sys

sys.path.insert(0, str((Path.cwd().parent / 'src').resolve()))

from modelb_semantic_repo.pipeline import run_pipeline

# %%
mode = 'paper'  # change to 'fast' or 'medium' as needed
outdir = Path('../results') / mode
run_pipeline(mode, outdir, seed=7)
outdir
